# %% [markdown]
# Simple Task
# Asking user their name through print statement

# %%
print("Hello user!")
name=input(("Please type your name here:"))
# Out:
# Hello user!

# %% [markdown]
# Display user's name

# %%
print(name)
# Out:
# vrusha

# %% [markdown]
# Taking user information

# %%
Name=input("Enter your name:")
Age=int(input("Enter your age:"))
City=input("Enter your city:")

# %%
print(Name)
print(Age)
print(City)
# Out:
# Sunita
# 20
# Ahmedabad
